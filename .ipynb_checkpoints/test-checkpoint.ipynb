# %%
using Plots
using TensorCrossInterpolation
using QuanticsTCI

# %%
B = 2^-30
function f(x)
    return cos(x / B) * cos( x / (4 * sqrt(5) * B)) * exp(-x^2) + 2*exp(-x)
    
end
# Out:
# f (generic function with 1 method)

# %%
xvals = range(0, 3, length=2^30)
qtt, ranks, errors = quanticscrossinterpolate(Float64, f, xvals; tolerance=1e-8)
# Out:
# (QuanticsTCI.QuanticsTensorCI2{Float64}(TensorCrossInterpolation.TensorCI2{Float64} with rank 21, QuanticsGrids.DiscretizedGrid{1}(30, (0.0,), (3.0,), 2, :interleaved, true), TensorCrossInterpolation.CachedFunction{Float64, BitIntegers.UInt256} with 39344 entries), [20, 23, 23, 21], [9.86588049162484e-9, 9.399904442530097e-9, 9.102550014882163e-9, 9.333390185923529e-9])

# %%
print(ranks)
# Out:
# [20, 23, 23, 21]

# %%
print(errors)
# Out:
# [9.86588049162484e-9, 9.399904442530097e-9, 9.102550014882163e-9, 9.333390185923529e-9]

# %%
plot(xvals[1:2^5], qtt.(1:2^5))
scatter!(xvals[1:2^5], f.(xvals[1:2^5]))

# %%
print(qtt)
# Out:
# QuanticsTCI.QuanticsTensorCI2{Float64}(TensorCrossInterpolation.TensorCI2{Float64} with rank 21, QuanticsGrids.DiscretizedGrid{1}(30, (0.0,), (3.0,), 2, :interleaved, true), TensorCrossInterpolation.CachedFunction{Float64, BitIntegers.UInt256} with 39344 entries)
